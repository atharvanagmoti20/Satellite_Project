# %%
import warnings
warnings.filterwarnings('ignore')

import os
import cv2
import glob
from tqdm import tqdm
from patchify import patchify
# from google.colab.patches import cv2_imshow
import numpy as np
import tensorflow as tf
import pandas as pd
from keras.models import Model, load_model
from skimage.morphology import label
import pickle
import tensorflow.python.keras.backend as K

from matplotlib import pyplot as plt
from tqdm import tqdm_notebook
import random
from skimage.io import imread, imshow, imread_collection, concatenate_images
from matplotlib import pyplot as plt
import h5py
import tifffile
from tifffile import imread

seed = 56

# %%
# !pip install patchify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.8/dist-packages (from patchify) (1.21.6)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
input_dir = r'/content/drive/MyDrive/Satellite_Data/sat'
output_dir = r'/content/Data/sat'
# scale_percent = 30

for file_name in os.listdir(input_dir):
    if file_name.endswith(".tiff"):
        # Load the image
        img_path = os.path.join(input_dir, file_name)
        img = cv2.imread(img_path)

        # Get the new dimensions
        width = 1024
        height = 1024
        dim = (width, height)

        # Resize the image
        resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

        # Save the resized image
        out_path = os.path.join(output_dir, file_name)
        cv2.imwrite(out_path, resized)

# %%
input_dir = r'/content/drive/MyDrive/Satellite_Data/map'
output_dir = r'/content/Data/map'
# scale_percent = 30

for file_name in os.listdir(input_dir):
    if file_name.endswith(".tif"):
        # Load the image
        img_path = os.path.join(input_dir, file_name)
        img = cv2.imread(img_path)

        # Get the new dimensions
        width = 1024
        height = 1024
        dim = (width, height)

        # Resize the image
        resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

        # Save the resized image
        out_path = os.path.join(output_dir, file_name)
        cv2.imwrite(out_path, resized)

# %%
# # Path to the directory containing the TIFF images
# input_directory = r'/content/Data/sat'

# # Path to the directory where the HDF5 files will be stored
# output_directory = r'/content/HDF5_Dataset/sat'

# # Create the output directory if it doesn't exist
# if not os.path.exists(output_directory):
#     os.makedirs(output_directory)

# # Loop through all TIFF images in the input directory
# for filename in os.listdir(input_directory):
#     # Skip files that are not TIFF images
#     if not filename.endswith('.tiff'):
#         continue
    
#     # Read the TIFF image data
#     image = cv2.imread(os.path.join(input_directory, filename))
    
#     # Create the HDF5 file
#     hdf5_file = h5py.File(os.path.join(output_directory, filename + '.h5py'), 'w')
    
#     # Create a dataset in the HDF5 file to store the image data
#     image_dataset = hdf5_file.create_dataset('image', data=image, compression='gzip')
    
#     # Close the HDF5 file
#     hdf5_file.close()

# %%
# # Path to the directory containing the TIFF images
# input_directory = r'/content/Data/map'

# # Path to the directory where the HDF5 files will be stored
# output_directory = r'/content/HDF5_Dataset/map'

# # Create the output directory if it doesn't exist
# if not os.path.exists(output_directory):
#     os.makedirs(output_directory)

# # Loop through all TIFF images in the input directory
# for filename in os.listdir(input_directory):
#     # Skip files that are not TIFF images
#     if not filename.endswith('.tif'):
#         continue
    
#     # Read the TIFF image data
#     image = cv2.imread(os.path.join(input_directory, filename))
    
#     # Create the HDF5 file
#     hdf5_file = h5py.File(os.path.join(output_directory, filename + '.hdf5'), 'w')
    
#     # Create a dataset in the HDF5 file to store the image data
#     image_dataset = hdf5_file.create_dataset('image', data=image, compression='gzip')
    
#     # Close the HDF5 file
#     hdf5_file.close()

# %%
WORKING_DIR = r'/content/Data'
NUMBER_OF_IMAGES = 49 #You can put maximum of 5598 i.e. equal to `len(TRAIN_IMG)`
IMG_WIDTH = 1024
IMG_HEIGHT = 1024
PATCH_SIZE = 256
IMG_CHANNEL = 3
IOU_THRESHOLD = 0.7

# Patches per image
NUMBER_OF_PATCHES_PER_IMG = int((IMG_WIDTH / PATCH_SIZE) * (IMG_WIDTH / PATCH_SIZE))
TOTAL_PATCHES = NUMBER_OF_IMAGES * NUMBER_OF_PATCHES_PER_IMG

# %%
TRAIN_IMG = sorted(glob.glob(WORKING_DIR + '/sat/*.tiff'))
TRAIN_MASK = sorted(glob.glob(WORKING_DIR + '/map/*.tif'))

# %%
image_dataset = []
for i, img in tqdm(enumerate(TRAIN_IMG)):
    if i== NUMBER_OF_IMAGES:
        break
    img_before_patch = cv2.imread(img) / 255
    img_patches = patchify(img_before_patch, (PATCH_SIZE, PATCH_SIZE, 3), step=PATCH_SIZE)
    img_patches = img_patches.reshape((NUMBER_OF_PATCHES_PER_IMG, PATCH_SIZE, PATCH_SIZE, 3))
    image_dataset.append(img_patches)
# Out:
# 49it [00:02, 20.54it/s]

# %%
images = np.array(image_dataset).reshape((NUMBER_OF_IMAGES * NUMBER_OF_PATCHES_PER_IMG, PATCH_SIZE, PATCH_SIZE, IMG_CHANNEL))
images.shape
# Out:
# (784, 256, 256, 3)

# %%
mask_dataset = []
for i, mask in tqdm(enumerate(TRAIN_MASK)):
    if i == NUMBER_OF_IMAGES:
        break
    mask_before_patch = cv2.imread(mask)[:, :, 0]
    mask_patches = patchify(mask_before_patch, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE)
    mask_patches = mask_patches.reshape((NUMBER_OF_PATCHES_PER_IMG, PATCH_SIZE, PATCH_SIZE))
    mask_dataset.append(mask_patches)
# Out:
# 49it [00:00, 63.88it/s]

# %%
masks = np.array(mask_dataset).reshape((NUMBER_OF_IMAGES * NUMBER_OF_PATCHES_PER_IMG, PATCH_SIZE, PATCH_SIZE))
masks.shape
# Out:
# (784, 256, 256)

# %%
plt.figure(figsize=(20,16))
x, y = 5,4
for i in range(y):  
    for j in range(x):
        plt.subplot(y*2, x, i*2*x+j+1)
        pos = i*120 + j*10
        plt.imshow(images[pos])
        plt.title('Sat img #{}'.format(pos))
        plt.axis('off')
        plt.subplot(y*2, x, (i*2+1)*x+j+1)
           
        #We display the associated mask we just generated above with the training image
        plt.imshow(masks[pos])
        plt.title('Mask #{}'.format(pos))
        plt.axis('off')
        
plt.show()

# %%
IMAGE_HEIGHT = IMAGE_WIDTH = 256
NUM_CHANNELS = 3

# %%
masks = np.expand_dims(masks, -1)

# %%
print(masks.shape)
print(images.shape)
# Out:
# (784, 256, 256, 1)
# (784, 256, 256, 3)

# %%
#Source: https://towardsdatascience.com/metrics-to-evaluate-your-semantic-segmentation-model-6bcb99639aa2
from keras import backend as K
def iou_coef(y_true, y_pred, smooth=1):
  y_true = tf.cast(y_true, tf.float32)
  y_pred = tf.cast(y_pred, tf.float32)
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  
  return iou

# %%
def dice_coef(y_true, y_pred, smooth = 1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def soft_dice_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return 1-dice_coef(y_true, y_pred)

# %%
from sklearn.model_selection import train_test_split
train_images, test_images, train_masks, test_masks = train_test_split(images, masks, test_size=0.25, random_state=seed)
del images, masks
print("TRAIN SET")
print(train_images.shape)
print(train_masks.shape)
print("TEST SET")
print(test_images.shape)
print(test_masks.shape)
# Out:
# TRAIN SET
# (588, 256, 256, 3)
# (588, 256, 256, 1)
# TEST SET
# (196, 256, 256, 3)
# (196, 256, 256, 1)

# %%
from keras.models import Model, load_model
import tensorflow as tf
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras import optimizers
from keras.layers import BatchNormalization
from tensorflow.python.keras.metrics import MeanIoU
import keras

# %%
inputs = Input((IMAGE_HEIGHT, IMAGE_WIDTH, 3))
s = Lambda(lambda x: x / 255) (inputs)

conv1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (inputs)
conv1 = BatchNormalization() (conv1)
conv1 = Dropout(0.1) (conv1)
conv1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv1)
conv1 = BatchNormalization() (conv1)
pooling1 = MaxPooling2D((2, 2)) (conv1)

conv2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (pooling1)
conv2 = BatchNormalization() (conv2)
conv2 = Dropout(0.1) (conv2)
conv2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv2)
conv2 = BatchNormalization() (conv2)
pooling2 = MaxPooling2D((2, 2)) (conv2)

conv3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (pooling2)
conv3 = BatchNormalization() (conv3)
conv3 = Dropout(0.2) (conv3)
conv3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv3)
conv3 = BatchNormalization() (conv3)
pooling3 = MaxPooling2D((2, 2)) (conv3)

conv4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (pooling3)
conv4 = BatchNormalization() (conv4)
conv4 = Dropout(0.2) (conv4)
conv4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv4)
conv4 = BatchNormalization() (conv4)
pooling4 = MaxPooling2D(pool_size=(2, 2)) (conv4)

conv5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (pooling4)
conv5 = BatchNormalization() (conv5)
conv5 = Dropout(0.3) (conv5)
conv5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv5)
conv5 = BatchNormalization() (conv5)


upsample6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (conv5)
upsample6 = concatenate([upsample6, conv4])
conv6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (upsample6)
conv6 = BatchNormalization() (conv6)
conv6 = Dropout(0.2) (conv6)
conv6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv6)
conv6 = BatchNormalization() (conv6)

upsample7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (conv6)
upsample7 = concatenate([upsample7, conv3])
conv7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (upsample7)
conv7 = BatchNormalization() (conv7)
conv7 = Dropout(0.2) (conv7)
conv7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv7)
conv7 = BatchNormalization() (conv7)

upsample8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (conv7)
upsample8 = concatenate([upsample8, conv2])
conv8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (upsample8)
conv8 = BatchNormalization() (conv8)
conv8 = Dropout(0.1) (conv8)
conv8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv8)
conv8 = BatchNormalization() (conv8)

upsample9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (conv8)
upsample9 = concatenate([upsample9, conv1], axis=3)
conv9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (upsample9)
conv9 = BatchNormalization() (conv9)
conv9 = Dropout(0.1) (conv9)
conv9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (conv9)
conv9 = BatchNormalization() (conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (conv9)

model = Model(inputs=[inputs], outputs=[outputs])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  dropout (Dropout)              (None, 256, 256, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['dropout[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  dropout_1 (Dropout)            (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['dropout_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 64, 64, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 32, 32, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['dropout_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['dropout_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  131200     ['batch_normalization_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_5[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  32832       ['batch_normalization_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_6[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  8224       ['batch_normalization_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 32  128        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2064       ['batch_normalization_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  dropout_8 (Dropout)            (None, 256, 256, 16  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  17          ['batch_normalization_17[0][0]']
#
# ==================================================================================================
# Total params: 1,946,993
# Trainable params: 1,944,049
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
EPOCHS = 100
LEARNING_RATE = 0.0001
BATCH_SIZE = 16

# %%
# !pip install tensorboardcolab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardcolab
#   Downloading tensorboardcolab-0.0.22.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: tensorboardcolab
#   Building wheel for tensorboardcolab (setup.py) ... done
#   Created wheel for tensorboardcolab: filename=tensorboardcolab-0.0.22-py3-none-any.whl size=3858 sha256=42e9bc72c521f86ab50f0690e5746101330210a67e8a354cf92279453276d68d
#   Stored in directory: /root/.cache/pip/wheels/e5/6b/92/99a181b543b45a45df4346bcdf01aac1f882fe447c63302878
# Successfully built tensorboardcolab
# Installing collected packages: tensorboardcolab
# Successfully installed tensorboardcolab-0.0.22

# %%
from tensorboardcolab import TensorBoardColab, TensorBoardColabCallback
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from datetime import datetime

# %%
tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://daa6-34-145-159-4.ngrok.io

# %%
checkpointer = tf.keras.callbacks.ModelCheckpoint("/content/Model/model_output1.h5", verbose=1, save_best_only=True)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=4, monitor='val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir="logs"),
    checkpointer
    ]

# %%
# from tensorflow.python.keras.optimizers import Adam

opt = keras.optimizers.Adam(LEARNING_RATE)
model.compile(
      optimizer=opt,
      loss=soft_dice_loss,
      metrics=[iou_coef], run_eagerly=True)

# %%
history = model.fit(train_images,
                    train_masks/255,
                    validation_split = 0.1,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks = callbacks
                       )
# Out:
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8955 - iou_coef: 0.0525
# Epoch 1: val_loss improved from inf to 0.91459, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 22s 342ms/step - loss: 0.8955 - iou_coef: 0.0525 - val_loss: 0.9146 - val_iou_coef: 0.0442
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8636 - iou_coef: 0.0704
# Epoch 2: val_loss improved from 0.91459 to 0.90210, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 277ms/step - loss: 0.8636 - iou_coef: 0.0704 - val_loss: 0.9021 - val_iou_coef: 0.0495
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8345 - iou_coef: 0.0814
# Epoch 3: val_loss did not improve from 0.90210
# 34/34 [==============================] - 9s 262ms/step - loss: 0.8345 - iou_coef: 0.0814 - val_loss: 0.9125 - val_iou_coef: 0.0428
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.8112 - iou_coef: 0.0981
# Epoch 4: val_loss improved from 0.90210 to 0.89618, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 276ms/step - loss: 0.8112 - iou_coef: 0.0981 - val_loss: 0.8962 - val_iou_coef: 0.0498
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7928 - iou_coef: 0.1066
# Epoch 5: val_loss did not improve from 0.89618
# 34/34 [==============================] - 9s 268ms/step - loss: 0.7928 - iou_coef: 0.1066 - val_loss: 0.8990 - val_iou_coef: 0.0483
# Epoch 6/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7831 - iou_coef: 0.1071
# Epoch 6: val_loss improved from 0.89618 to 0.84951, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 266ms/step - loss: 0.7831 - iou_coef: 0.1071 - val_loss: 0.8495 - val_iou_coef: 0.0666
# Epoch 7/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7735 - iou_coef: 0.1104
# Epoch 7: val_loss did not improve from 0.84951
# 34/34 [==============================] - 9s 265ms/step - loss: 0.7735 - iou_coef: 0.1104 - val_loss: 0.8812 - val_iou_coef: 0.0546
# Epoch 8/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7654 - iou_coef: 0.1173
# Epoch 8: val_loss improved from 0.84951 to 0.79902, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 282ms/step - loss: 0.7654 - iou_coef: 0.1173 - val_loss: 0.7990 - val_iou_coef: 0.0903
# Epoch 9/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7570 - iou_coef: 0.1178
# Epoch 9: val_loss improved from 0.79902 to 0.77896, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 265ms/step - loss: 0.7570 - iou_coef: 0.1178 - val_loss: 0.7790 - val_iou_coef: 0.1006
# Epoch 10/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7478 - iou_coef: 0.1236
# Epoch 10: val_loss did not improve from 0.77896
# 34/34 [==============================] - 9s 264ms/step - loss: 0.7478 - iou_coef: 0.1236 - val_loss: 0.7967 - val_iou_coef: 0.0931
# Epoch 11/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7384 - iou_coef: 0.1281
# Epoch 11: val_loss did not improve from 0.77896
# 34/34 [==============================] - 9s 277ms/step - loss: 0.7384 - iou_coef: 0.1281 - val_loss: 0.7864 - val_iou_coef: 0.1026
# Epoch 12/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7283 - iou_coef: 0.1355
# Epoch 12: val_loss improved from 0.77896 to 0.75895, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 268ms/step - loss: 0.7283 - iou_coef: 0.1355 - val_loss: 0.7589 - val_iou_coef: 0.1142
# Epoch 13/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7204 - iou_coef: 0.1382
# Epoch 13: val_loss improved from 0.75895 to 0.73605, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 277ms/step - loss: 0.7204 - iou_coef: 0.1382 - val_loss: 0.7360 - val_iou_coef: 0.1237
# Epoch 14/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7123 - iou_coef: 0.1448
# Epoch 14: val_loss improved from 0.73605 to 0.71716, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 284ms/step - loss: 0.7123 - iou_coef: 0.1448 - val_loss: 0.7172 - val_iou_coef: 0.1341
# Epoch 15/100
# 34/34 [==============================] - ETA: 0s - loss: 0.7026 - iou_coef: 0.1547
# Epoch 15: val_loss improved from 0.71716 to 0.68363, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 266ms/step - loss: 0.7026 - iou_coef: 0.1547 - val_loss: 0.6836 - val_iou_coef: 0.1534
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6911 - iou_coef: 0.1542
# Epoch 16: val_loss improved from 0.68363 to 0.67448, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 273ms/step - loss: 0.6911 - iou_coef: 0.1542 - val_loss: 0.6745 - val_iou_coef: 0.1582
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6847 - iou_coef: 0.1656
# Epoch 17: val_loss improved from 0.67448 to 0.64670, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 273ms/step - loss: 0.6847 - iou_coef: 0.1656 - val_loss: 0.6467 - val_iou_coef: 0.1728
# Epoch 18/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6708 - iou_coef: 0.1714
# Epoch 18: val_loss improved from 0.64670 to 0.64257, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 266ms/step - loss: 0.6708 - iou_coef: 0.1714 - val_loss: 0.6426 - val_iou_coef: 0.1757
# Epoch 19/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6623 - iou_coef: 0.1766
# Epoch 19: val_loss improved from 0.64257 to 0.62558, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 273ms/step - loss: 0.6623 - iou_coef: 0.1766 - val_loss: 0.6256 - val_iou_coef: 0.1861
# Epoch 20/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6522 - iou_coef: 0.1799
# Epoch 20: val_loss did not improve from 0.62558
# 34/34 [==============================] - 9s 267ms/step - loss: 0.6522 - iou_coef: 0.1799 - val_loss: 0.6284 - val_iou_coef: 0.1850
# Epoch 21/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6420 - iou_coef: 0.1908
# Epoch 21: val_loss improved from 0.62558 to 0.60881, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 267ms/step - loss: 0.6420 - iou_coef: 0.1908 - val_loss: 0.6088 - val_iou_coef: 0.1988
# Epoch 22/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6332 - iou_coef: 0.1962
# Epoch 22: val_loss improved from 0.60881 to 0.58481, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 273ms/step - loss: 0.6332 - iou_coef: 0.1962 - val_loss: 0.5848 - val_iou_coef: 0.2115
# Epoch 23/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6246 - iou_coef: 0.1991
# Epoch 23: val_loss improved from 0.58481 to 0.56557, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 284ms/step - loss: 0.6246 - iou_coef: 0.1991 - val_loss: 0.5656 - val_iou_coef: 0.2233
# Epoch 24/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6127 - iou_coef: 0.2055
# Epoch 24: val_loss did not improve from 0.56557
# 34/34 [==============================] - 9s 259ms/step - loss: 0.6127 - iou_coef: 0.2055 - val_loss: 0.5673 - val_iou_coef: 0.2235
# Epoch 25/100
# 34/34 [==============================] - ETA: 0s - loss: 0.6023 - iou_coef: 0.2179
# Epoch 25: val_loss improved from 0.56557 to 0.55418, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 275ms/step - loss: 0.6023 - iou_coef: 0.2179 - val_loss: 0.5542 - val_iou_coef: 0.2327
# Epoch 26/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5945 - iou_coef: 0.2215
# Epoch 26: val_loss did not improve from 0.55418
# 34/34 [==============================] - 9s 267ms/step - loss: 0.5945 - iou_coef: 0.2215 - val_loss: 0.5544 - val_iou_coef: 0.2302
# Epoch 27/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5786 - iou_coef: 0.2228
# Epoch 27: val_loss improved from 0.55418 to 0.54270, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 266ms/step - loss: 0.5786 - iou_coef: 0.2228 - val_loss: 0.5427 - val_iou_coef: 0.2387
# Epoch 28/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5723 - iou_coef: 0.2322
# Epoch 28: val_loss improved from 0.54270 to 0.53719, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 273ms/step - loss: 0.5723 - iou_coef: 0.2322 - val_loss: 0.5372 - val_iou_coef: 0.2404
# Epoch 29/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5619 - iou_coef: 0.2413
# Epoch 29: val_loss improved from 0.53719 to 0.53102, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 284ms/step - loss: 0.5619 - iou_coef: 0.2413 - val_loss: 0.5310 - val_iou_coef: 0.2459
# Epoch 30/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5534 - iou_coef: 0.2467
# Epoch 30: val_loss improved from 0.53102 to 0.52584, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 267ms/step - loss: 0.5534 - iou_coef: 0.2467 - val_loss: 0.5258 - val_iou_coef: 0.2493
# Epoch 31/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5409 - iou_coef: 0.2453
# Epoch 31: val_loss improved from 0.52584 to 0.50826, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 275ms/step - loss: 0.5409 - iou_coef: 0.2453 - val_loss: 0.5083 - val_iou_coef: 0.2633
# Epoch 32/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5296 - iou_coef: 0.2571
# Epoch 32: val_loss improved from 0.50826 to 0.48812, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 283ms/step - loss: 0.5296 - iou_coef: 0.2571 - val_loss: 0.4881 - val_iou_coef: 0.2773
# Epoch 33/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5212 - iou_coef: 0.2725
# Epoch 33: val_loss improved from 0.48812 to 0.47267, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 266ms/step - loss: 0.5212 - iou_coef: 0.2725 - val_loss: 0.4727 - val_iou_coef: 0.2874
# Epoch 34/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5126 - iou_coef: 0.2681
# Epoch 34: val_loss did not improve from 0.47267
# 34/34 [==============================] - 9s 266ms/step - loss: 0.5126 - iou_coef: 0.2681 - val_loss: 0.4824 - val_iou_coef: 0.2832
# Epoch 35/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5045 - iou_coef: 0.2841
# Epoch 35: val_loss improved from 0.47267 to 0.44972, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 285ms/step - loss: 0.5045 - iou_coef: 0.2841 - val_loss: 0.4497 - val_iou_coef: 0.3042
# Epoch 36/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4934 - iou_coef: 0.2879
# Epoch 36: val_loss did not improve from 0.44972
# 34/34 [==============================] - 9s 257ms/step - loss: 0.4934 - iou_coef: 0.2879 - val_loss: 0.4697 - val_iou_coef: 0.2961
# Epoch 37/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4869 - iou_coef: 0.2889
# Epoch 37: val_loss did not improve from 0.44972
# 34/34 [==============================] - 9s 265ms/step - loss: 0.4869 - iou_coef: 0.2889 - val_loss: 0.4501 - val_iou_coef: 0.3102
# Epoch 38/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4813 - iou_coef: 0.2992
# Epoch 38: val_loss improved from 0.44972 to 0.44596, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 285ms/step - loss: 0.4813 - iou_coef: 0.2992 - val_loss: 0.4460 - val_iou_coef: 0.3090
# Epoch 39/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4682 - iou_coef: 0.3077
# Epoch 39: val_loss did not improve from 0.44596
# 34/34 [==============================] - 9s 258ms/step - loss: 0.4682 - iou_coef: 0.3077 - val_loss: 0.4492 - val_iou_coef: 0.3042
# Epoch 40/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4603 - iou_coef: 0.3176
# Epoch 40: val_loss improved from 0.44596 to 0.44579, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 274ms/step - loss: 0.4603 - iou_coef: 0.3176 - val_loss: 0.4458 - val_iou_coef: 0.3089
# Epoch 41/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4547 - iou_coef: 0.3177
# Epoch 41: val_loss improved from 0.44579 to 0.42449, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 284ms/step - loss: 0.4547 - iou_coef: 0.3177 - val_loss: 0.4245 - val_iou_coef: 0.3226
# Epoch 42/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4460 - iou_coef: 0.3198
# Epoch 42: val_loss did not improve from 0.42449
# 34/34 [==============================] - 9s 258ms/step - loss: 0.4460 - iou_coef: 0.3198 - val_loss: 0.4416 - val_iou_coef: 0.3112
# Epoch 43/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4398 - iou_coef: 0.3164
# Epoch 43: val_loss did not improve from 0.42449
# 34/34 [==============================] - 9s 267ms/step - loss: 0.4398 - iou_coef: 0.3164 - val_loss: 0.4293 - val_iou_coef: 0.3192
# Epoch 44/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4306 - iou_coef: 0.3350
# Epoch 44: val_loss improved from 0.42449 to 0.42009, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 278ms/step - loss: 0.4306 - iou_coef: 0.3350 - val_loss: 0.4201 - val_iou_coef: 0.3249
# Epoch 45/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4283 - iou_coef: 0.3329
# Epoch 45: val_loss improved from 0.42009 to 0.41897, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 9s 266ms/step - loss: 0.4283 - iou_coef: 0.3329 - val_loss: 0.4190 - val_iou_coef: 0.3257
# Epoch 46/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4205 - iou_coef: 0.3354
# Epoch 46: val_loss did not improve from 0.41897
# 34/34 [==============================] - 9s 267ms/step - loss: 0.4205 - iou_coef: 0.3354 - val_loss: 0.4221 - val_iou_coef: 0.3246
# Epoch 47/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4044 - iou_coef: 0.3563
# Epoch 47: val_loss improved from 0.41897 to 0.40761, saving model to /content/Model/model_output1.h5
# 34/34 [==============================] - 10s 285ms/step - loss: 0.4044 - iou_coef: 0.3563 - val_loss: 0.4076 - val_iou_coef: 0.3240
# Epoch 48/100
# 34/34 [==============================] - ETA: 0s - loss: 0.4035 - iou_coef: 0.3560
# Epoch 48: val_loss did not improve from 0.40761
# 34/34 [==============================] - 9s 258ms/step - loss: 0.4035 - iou_coef: 0.3560 - val_loss: 0.4101 - val_iou_coef: 0.3366
# Epoch 49/100
# 34/34 [==============================] - ETA: 0s - loss: 0.3978 - iou_coef: 0.3592
# Epoch 49: val_loss did not improve from 0.40761
# 34/34 [==============================] - 9s 264ms/step - loss: 0.3978 - iou_coef: 0.3592 - val_loss: 0.4316 - val_iou_coef: 0.3182
# Epoch 50/100
# 34/34 [==============================] - ETA: 0s - loss: 0.3972 - iou_coef: 0.3586
# Epoch 50: val_loss did not improve from 0.40761
# 34/34 [==============================] - 9s 275ms/step - loss: 0.3972 - iou_coef: 0.3586 - val_loss: 0.4203 - val_iou_coef: 0.3283
# Epoch 51/100
# 34/34 [==============================] - ETA: 0s - loss: 0.3883 - iou_coef: 0.3734
# Epoch 51: val_loss did not improve from 0.40761
# 34/34 [==============================] - 9s 258ms/step - loss: 0.3883 - iou_coef: 0.3734 - val_loss: 0.4222 - val_iou_coef: 0.3260

# %%
model.save(r"/content/Model/model_output1.h5")

# %%
model = load_model("/content/Model/model_output1.h5", custom_objects={'soft_dice_loss': soft_dice_loss, 'iou_coef': iou_coef})

# %%
model.evaluate(test_images, test_masks/255)
# Out:
# 7/7 [==============================] - 3s 169ms/step - loss: 0.3973 - iou_coef: 0.3459
# [0.3973272144794464, 0.34585484862327576]

# %%
predictions = model.predict(test_images, verbose=1)
# Out:
# 7/7 [==============================] - 1s 86ms/step

# %%
thresh_val = 0.1
predicton_threshold = (predictions > thresh_val).astype(np.uint8)

# %%
ix = random.randint(0, len(predictions))
num_samples = 10

f = plt.figure(figsize = (15, 25))
for i in range(1, num_samples*4, 4):
  ix = random.randint(0, len(predictions))

  f.add_subplot(num_samples, 4, i)
  imshow(test_images[ix][:,:,0])
  plt.title("Image")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+1)
  imshow(np.squeeze(test_masks[ix][:,:,0]))
  plt.title("Groud Truth")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+2)
  imshow(np.squeeze(predictions[ix][:,:,0]))
  plt.title("Prediction")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+3)
  imshow(np.squeeze(predicton_threshold[ix][:,:,0]))
  plt.title("thresholded at {}".format(thresh_val))
  plt.axis('off')

plt.show()
